# %%
def weird_func(x, y, z, debug_file=None, debug=False):
    print('req args:', x, y, z)
    print('file', debug_file)
    print('debug', debug)

# %%
weird_func()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/13678895.py in <module>
# ----> 1 weird_func()
#
# TypeError: weird_func() missing 3 required positional arguments: 'x', 'y', and 'z'

# %%
weird_func(3, 2, 1)
# Out:
# req args: 3 2 1
# file None
# debug False

# %%
weird_func(1, 2, 3, 'foo.txt', True)
# Out:
# req args: 1 2 3
# file foo.txt
# debug True

# %%
weird_func(1, 2, 3, debug=True)
# Out:
# req args: 1 2 3
# file None
# debug True

# %%
def weird_func(x, y, z, *, debug_file=None, debug=False):
    print('req args:', x, y, z)
    print('file', debug_file)
    print('debug', debug)

# %%
weird_func(1, 2, 3, 'foo.txt', True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/2753153424.py in <module>
# ----> 1 weird_func(1, 2, 3, 'foo.txt', True)
#
# TypeError: weird_func() takes 3 positional arguments but 5 were given

# %%
weird_func(1, 2, 3, debug=True, debug_file='foo.txt')
# Out:
# req args: 1 2 3
# file foo.txt
# debug True

# %%
import sys
sys.version
# Out:
# '3.7.12 | packaged by conda-forge | (default, Oct 26 2021, 06:08:53) \n[GCC 9.4.0]'

# %%
weird_func(y=2, x=3, z=1, debug=True, debug_file='something')
# Out:
# req args: 3 2 1
# file something
# debug True

# %%
def weird_func(x, y, z, /, *, debug_file=None, debug=False):
    print('req args:', x, y, z)
    print('file', debug_file)
    print('debug', debug)
# Out:
#   File "/tmp/ipykernel_80/1094807509.py", line 1
#     def weird_func(x, y, z, /, *, debug_file=None, debug=False):
#                             ^
# SyntaxError: invalid syntax

# %%
sorted('string')
# Out:
# ['g', 'i', 'n', 'r', 's', 't']

# %%
sorted(iterable='string')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/2317272095.py in <module>
# ----> 1 sorted(iterable='string')
#
# TypeError: sorted expected 1 arguments, got 0

# %%
import math

# %%
help(math.sin)
# Out:
# Help on built-in function sin in module math:
#
# sin(x, /)
#     Return the sine of x (measured in radians).

# %%
math.sin(x=math.pi/2.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/2613336370.py in <module>
# ----> 1 math.sin(x=math.pi/2.0)
#
# TypeError: sin() takes no keyword arguments

# %%
ord('A')
# Out:
# 65

# %%
ord('alpha')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_131/621652749.py in <module>
# ----> 1 ord('alpha')
#
# TypeError: ord() expected a character, but string of length 5 found

# %%
divmod('9', '5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_131/3017630932.py in <module>
# ----> 1 divmod('9', '5')
#
# TypeError: unsupported operand type(s) for divmod(): 'str' and 'str'

# %%
d = {}

# %%
d['one']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_131/326205724.py in <module>
# ----> 1 d['one']
#
# KeyError: 'one'

# %%
d = { 'one': 1, 'one': 2}

# %%
d['one']
# Out:
# 2

# %%
d['one'] = 2

# %%
d
# Out:
# {'one': 2}

# %%
def calculate(val1, val2, oper): # 2, 4, '+'
    if oper == '+':
        return val1 + val2

# %%
calculate(1, 2, '+')
# Out:
# 3

# %%
def calculate(val1, val2, oper): # 2, 4, '+'
    if oper == '+':
        return val1 + val2
    if oper == '/':
        try:
            return val1 / val2
        except ZeroDivisionError:
            return None

# %%
def calculate(val1, val2, oper): # 2, 4, '+'
    if oper == '+':
        return val1 + val2, None
    if oper == '/':
        try:
            return val1 / val2, None
        except ZeroDivisionError:
            return 0, 'Tried to divide by zero'

# %%
print(calculate(3, 0, '/'))
# Out:
# (0, 'Tried to divide by zero')

# %%
# LBYL vs. EAFP styles of programming
# LBYL = Look Before You Leap
# EAFP = Easier to Ask Forgiveness than Permission

# %%
d = {'one': 'won'}

# %%
key = 'one'

# %%
# EAFP style
try:
    print(d[key])
except KeyError:
    print('bad key:', key)
# Out:
# won

# %%
# LBYL style
d.get(key, 'not there') # will return the value if the key exists, otherwise return None (or something we specify)
# Out:
# 'won'

# %%
# LBYL style
if key in d: # is key a key in this dict
    print(d[key])
# Out:
# won

# %%
response = ' x456 '

# %%
if response.strip().isdigit():
    print(int(response))

# %%
int(response)
# Out:
# 456

# %%
try:
    response = int(response)
except ValueError:
    print('not a number')
# Out:
# not a number

# %%
# my recommendation...do LBYL if it's easy, otherwise do EAFP

# %%
def sqrt(num):
    if num < 0:
        raise ValueError('Cannot compute sqrt < 0')

# %%
sqrt(-4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_165/2365620970.py in <module>
# ----> 1 sqrt(-4)
#
# /tmp/ipykernel_165/4144092323.py in sqrt(num)
#       1 def sqrt(num):
#       2     if num < 0:
# ----> 3         raise ValueError('Cannot compute sqrt < 0')
#
# ValueError: Cannot compute sqrt < 0

# %%
def sqrt(num):
    """Compute the square root of a positive number (int or float)"""
    if num < 0:
        raise ValueError('Cannot compute sqrt < 0')
    import math
    return math.sqrt(num)

# %%
sqrt(4.5)
# Out:
# 2.1213203435596424

# %%
def sqrt(num):
    """Compute the square root of a positive number (int or float)"""
    if num < 0:
        raise ValueError('Cannot compute sqrt < 0')
    import math
    return math.sqrt(num)

# %%
sqrt('number')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_165/2996775916.py in <module>
# ----> 1 sqrt('number')
#
# /tmp/ipykernel_165/1664852974.py in sqrt(num)
#       1 def sqrt(num):
#       2     """Compute the square root of a positive number (int or float)"""
# ----> 3     if num < 0:
#       4         raise ValueError('Cannot compute sqrt < 0')
#       5     import math
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %% [markdown]
# ### def sqrt(num):
#     """Compute the square root of a positive number (int or float)"""
#     if type(num) not in (int, float):
#         raise TypeError('compute sqrt of int of float only')
#     if num < 0.0:
#         raise ValueError('Cannot compute sqrt < 0')
#     import math
#     return math.sqrt(num)

# %%
type({int, float})
# Out:
# set

# %%
sqrt(-4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_165/2365620970.py in <module>
# ----> 1 sqrt(-4)
#
# /tmp/ipykernel_165/1904469265.py in sqrt(num)
#       4         raise TypeError('compute sqrt of int of float only')
#       5     if num < 0.0:
# ----> 6         raise ValueError('Cannot compute sqrt < 0')
#       7     import math
#       8     return math.sqrt(num)
#
# ValueError: Cannot compute sqrt < 0

# %%
sqrt('4')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_165/2016157371.py in <module>
# ----> 1 sqrt('4')
#
# /tmp/ipykernel_165/1904469265.py in sqrt(num)
#       2     """Compute the square root of a positive number (int or float)"""
#       3     if type(num) not in (int, float):
# ----> 4         raise TypeError('compute sqrt of int of float only')
#       5     if num < 0.0:
#       6         raise ValueError('Cannot compute sqrt < 0')
#
# TypeError: compute sqrt of int of float only

# %%
sqrt(4)
# Out:
# 2.0

# %%
def calculate(val1, val2, oper): # 2, 4, '+'
    if oper == '+':
        return val1 + val2
    if oper == '/':
        if val2 == 0: # only doable for ints (not a good idea to compare a float with 0)
            raise ZeroDivisionError('Cannot divide by 0')
        return val1 / val2

# %%
calculate(3, 0.0, '/')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_165/4123893121.py in <module>
# ----> 1 calculate(3, 0.0, '/')
#
# /tmp/ipykernel_165/2542762976.py in calculate(val1, val2, oper)
#       4     if oper == '/':
#       5         if val2 == 0: # only doable for ints (not a good idea to compare a float with 0)
# ----> 6             raise ZeroDivisionError('Cannot divide by 0')
#       7         return val1 / val2
#
# ZeroDivisionError: Cannot divide by 0
