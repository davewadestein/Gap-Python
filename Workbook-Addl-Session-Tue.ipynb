# %%
def weird_func(x, y, z, debug_file=None, debug=False):
    print('req args:', x, y, z)
    print(debug_file)
    print(debug)

# %%
weird_func(1, 2, 3)
# Out:
# req args: 1 2 3
# None
# False

# %%
weird_func(1, 2, 3, 'outfile.txt', True)
# Out:
# req args: 1 2 3
# outfile.txt
# True

# %%
weird_func(1, 2, 3, debug_file='outfile.txt', debug=True)
# Out:
# req args: 1 2 3
# outfile.txt
# True

# %%
weird_func(1, 2, 3, debug=True, debug_file='outfile.txt')
# Out:
# req args: 1 2 3
# outfile.txt
# True

# %%
weird_func(1, 2, 3, debug=True)
# Out:
# req args: 1 2 3
# None
# True

# %%
def weird_func(x, y, z, *, debug_file=None, debug=False):
    # * says all args to the right must be passed by keyword
    print('req args:', x, y, z)
    print(debug_file)
    print(debug)

# %%
weird_func(1, 2, 3, 'outfile.txt', True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_97/3303237848.py in <module>
# ----> 1 weird_func(1, 2, 3, 'outfile.txt', True)
#
# TypeError: weird_func() takes 3 positional arguments but 5 were given

# %%
weird_func(1, 2, 3, debug=True, debug_file='outfile.txt')
# Out:
# req args: 1 2 3
# outfile.txt
# True

# %%
weird_func(z=1, x=2, y=3, debug=True, debug_file='outfile.txt')
# Out:
# req args: 2 3 1
# outfile.txt
# True

# %%
def weird_func(x, y, z, /, *, debug_file=None, debug=False):
    # / says all args to left must be passed POSITIONALLY
    # * says all args to the right must be passed by keyword
    print('req args:', x, y, z)
    print(debug_file)
    print(debug)
# Out:
#   File "/tmp/ipykernel_97/3513405311.py", line 1
#     def weird_func(x, y, z, /, *, debug_file=None, debug=False):
#                             ^
# SyntaxError: invalid syntax

# %%
sorted(iterable=[3, 1, 3, 5, 2, -43, 6], reverse=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_97/2190162060.py in <module>
# ----> 1 sorted(iterable=[3, 1, 3, 5, 2, -43, 6], reverse=True)
#
# TypeError: sorted expected 1 arguments, got 0

# %%
import math

# %%
help(math.sin)
# Out:
# Help on built-in function sin in module math:
#
# sin(x, /)
#     Return the sine of x (measured in radians).

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sin(x=math.pi/2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_97/1329931262.py in <module>
# ----> 1 math.sin(x=math.pi/2)
#
# TypeError: sin() takes no keyword arguments

# %%
def f(one, two):
    print(one, two)

# %%
f(1, 2)
# Out:
# 1 2

# %%
f(one=2, two=1)
# Out:
# 2 1

# %%
f(1, two=2)
# Out:
# 1 2

# %%
f(two=2, one='one')
# Out:
# one 2

# %%
def f(one, two, ftype='rotate', debug=False):
    print(one, two)

# %%
f(1, 2, 'square', True)
# Out:
# 1 2

# %%
def f(one, two, *, ftype='rotate', debug=False):
    print(one, two)

# %%
f(1, 2, ftype='square', debug=True)
# Out:
# 1 2

# %%
num = input('Enter a number: ')
# Out:
# Enter a number:  hello

# %%
int(num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_97/231934671.py in <module>
# ----> 1 int(num)
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
def a():
    b()
    
def b():
    c()
    
def c():
    int('hello')

# %%
a()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_97/3657634075.py in <module>
# ----> 1 a()
#
# /tmp/ipykernel_97/918354092.py in a()
#       1 def a():
# ----> 2     b()
#       3
#       4 def b():
#       5     c()
#
# /tmp/ipykernel_97/918354092.py in b()
#       3
#       4 def b():
# ----> 5     c()
#       6
#       7 def c():
#
# /tmp/ipykernel_97/918354092.py in c()
#       6
#       7 def c():
# ----> 8     int('hello')
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
d = {}

# %%
d['2']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_97/3667968006.py in <module>
# ----> 1 d['2']
#
# KeyError: '2'

# %%
def calc(num1, num2, oper):
    """Perform a calculation: num1 oper num2, where oper either +, -, *, /"""
    pass

# %%
calc(2, 3, '+')

# %%
def calc(num1, num2, oper):
    """Perform a calculation: num1 oper num2, where oper either +, -, *, /"""
    # LBYL style
    if oper == '+':
        return num1 + num2
    if oper == '/':
        if num2 == 0:
            print('Unable to divide by 0!')
            return None
        else:
            return num1 / num2
        
    # something else...?

# %%
print(calc(3, 0, '/'))
# Out:
# Unable to divide by 0!
# None

# %%
def calc(num1, num2, oper):
    """Perform a calculation: num1 oper num2, where oper either +, -, *, /"""
    # EAFP style
    if oper == '+':
        return num1 + num2
    if oper == '/':
        result = None
        try:
            result = num1 / num2
        except ZeroDivisionError:
            print('Hey, no dividing by zero!')
        return result # either a number of None

# %%
calc(3, 0, '/')
# Out:
# Hey, no dividing by zero!

# %%
# LBYL vs. EAFP
# LBYL = Look Before You Leap
# EAFP = Easier to Ask Forgiveness than Permission

# %%
def func():
    try:
        # line 
    except this:
        return 'bad'
    try:
        # line 2
    except that:
        something else
        
        # line 3
        # line 1
        # line 2
        # line 3
        # line 1
        # line 2
        # line 3
        # line 1
        # line 2
        # line 3
    except IndexError:
        print('blah')
        
    return True

# %%
num = input('Enter num: ')
if num.strip().isdigit(): # strip spaces and check to see if input is digits only
    print(int(num))
# Out:
# Enter num:     -34

# %%
int(num)
# Out:
# 456

# %%
# do LBYL if easy (!), otherwise EAFP

# %%
d = { 'one': 1, 'two': 3 }

# %%
print(d.get('key', 'not there'))
# Out:
# not there

# %%
# EAFP style
key = input('Enter dict key: ')
try:
    print(d[key])
except KeyError:
    print('not a valid key')
# Out:
# Enter dict key:  bad key
# not a valid key

# %%
key = input('Enter dict key: ')

if key in d:
    print(d[key])
else:
    print('not a valid key')
# Out:
# Enter dict key:  three
# not a valid key

# %%
# pseudocode
try:
    dangerous_call()
except OS_Error:
    log('...')

after_call()

# %%
def sqrt(num):
    if type(num) not in (int, float):
        raise TypeError("Can only compute sqrt of ints or floats")
    if num < 0:
        raise ValueError("Can't compute sqrt of negative number!")
    import math
    return math.sqrt(num)

# %%
sqrt(-3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_131/2412230592.py in <module>
# ----> 1 sqrt(-3)
#
# /tmp/ipykernel_131/4069085128.py in sqrt(num)
#       3         raise TypeError("Can only compute sqrt of ints or floats")
#       4     if num < 0:
# ----> 5         raise ValueError("Can't compute sqrt of negative number!")
#       6     import math
#       7     return math.sqrt(num)
#
# ValueError: Can't compute sqrt of negative number!

# %%
sqrt(3)
# Out:
# 1.7320508075688772

# %%
sqrt('3')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_131/3910007862.py in <module>
# ----> 1 sqrt('3')
#
# /tmp/ipykernel_131/4069085128.py in sqrt(num)
#       1 def sqrt(num):
#       2     if type(num) not in (int, float):
# ----> 3         raise TypeError("Can only compute sqrt of ints or floats")
#       4     if num < 0:
#       5         raise ValueError("Can't compute sqrt of negative number!")
#
# TypeError: Can only compute sqrt of ints or floats

# %%
def weird_func():
    try:
        int('blah')
    except ValueError:
        raise TypeError('raise another')

# %%
try:
    weird_func()
except TypeError:
    print('weird_func barfed')
# Out:
# weird_func barfed
